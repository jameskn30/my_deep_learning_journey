# %%
import io
import os
import re
import shutil
import string
import tensorflow as tf

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.layers import TextVectorization

import matplotlib.pyplot as plt

# %% [markdown]
# # Text Encoding
#
# 1. hot encoding : for each word, vectorize the word to a vector of vocabulary length and 99% of it is 0s. *Insufficient*!!
#
# 2. encode to numbers:
#   - it's hard to learn the relationship between each word
#   - hard to interpret
#
# 3. Work embedding:
#   - dense and efficient way to represent a word. similiar words can be embedded similiarly
#   - you can train it (the more dimensions - you can specify it, the more data required to train)

# %%
batch_size = 1024
seed = 123
vocab_size = 1000
embedding_size = 16
sequence_length = 250

# %%
#Load IMDB datasets
url = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"
dataset = tf.keras.utils.get_file("aclImdb_v1.tar.gz", url,
                                  untar=True, cache_dir='.',
                                  cache_subdir='')

dataset_dir = os.path.join(os.path.dirname(dataset), 'aclImdb')

#remove a directory called unsup in train dir
remove_dir = os.path.join(dataset_dir, 'train','unsup')
shutil.rmtree(remove_dir)

print(os.listdir(dataset_dir))
print(os.listdir(os.path.join(dataset_dir, "train")))
print(os.listdir(os.path.join(dataset_dir, "test")))
# Out:
# Downloading data from https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# 84125825/84125825 [==============================] - 4s 0us/step
# ['imdb.vocab', 'imdbEr.txt', 'test', 'README', 'train']
# ['neg', 'urls_pos.txt', 'pos', 'unsupBow.feat', 'urls_neg.txt', 'labeledBow.feat', 'urls_unsup.txt']
# ['neg', 'urls_pos.txt', 'pos', 'urls_neg.txt', 'labeledBow.feat']

# %%
#Load dataset to train_ds, valid_ds
train_ds = tf.keras.utils.text_dataset_from_directory(
    os.path.join(dataset_dir, 'train'),
    batch_size = batch_size, 
    subset="training",
    seed = seed,
    validation_split=0.2
    )

valid_ds = tf.keras.utils.text_dataset_from_directory(
    os.path.join(dataset_dir, 'train'),
    batch_size = batch_size, 
    subset="validation",
    seed = seed,
    validation_split=0.2
    )
test_ds = tf.keras.utils.text_dataset_from_directory(
    os.path.join(dataset_dir, 'test'),
    batch_size=batch_size,
    shuffle=False,
)

#EDA
for text_batch, label_batch in train_ds.take(1):
  for i in range(3):
    print("Review", text_batch.numpy()[i])
    print("Label", label_batch.numpy()[i])

print("labels ", train_ds.class_names)
# Out:
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.
# Found 25000 files belonging to 2 classes.
# Review b"Oh My God! Please, for the love of all that is holy, Do Not Watch This Movie! It it 82 minutes of my life I will never get back. Sure, I could have stopped watching half way through. But I thought it might get better. It Didn't. Anyone who actually enjoyed this movie is one seriously sick and twisted individual. No wonder us Australians/New Zealanders have a terrible reputation when it comes to making movies. Everything about this movie is horrible, from the acting to the editing. I don't even normally write reviews on here, but in this case I'll make an exception. I only wish someone had of warned me before I hired this catastrophe"
# Label 0
# Review b'This movie is SOOOO funny!!! The acting is WONDERFUL, the Ramones are sexy, the jokes are subtle, and the plot is just what every high schooler dreams of doing to his/her school. I absolutely loved the soundtrack as well as the carefully placed cynicism. If you like monty python, You will love this film. This movie is a tad bit "grease"esk (without all the annoying songs). The songs that are sung are likable; you might even find yourself singing these songs once the movie is through. This musical ranks number two in musicals to me (second next to the blues brothers). But please, do not think of it as a musical per say; seeing as how the songs are so likable, it is hard to tell a carefully choreographed scene is taking place. I think of this movie as more of a comedy with undertones of romance. You will be reminded of what it was like to be a rebellious teenager; needless to say, you will be reminiscing of your old high school days after seeing this film. Highly recommended for both the family (since it is a very youthful but also for adults since there are many jokes that are funnier with age and experience.'
# Label 1
# Review b"Alex D. Linz replaces Macaulay Culkin as the central figure in the third movie in the Home Alone empire. Four industrial spies acquire a missile guidance system computer chip and smuggle it through an airport inside a remote controlled toy car. Because of baggage confusion, grouchy Mrs. Hess (Marian Seldes) gets the car. She gives it to her neighbor, Alex (Linz), just before the spies turn up. The spies rent a house in order to burglarize each house in the neighborhood until they locate the car. Home alone with the chicken pox, Alex calls 911 each time he spots a theft in progress, but the spies always manage to elude the police while Alex is accused of making prank calls. The spies finally turn their attentions toward Alex, unaware that he has rigged devices to cleverly booby-trap his entire house. Home Alone 3 wasn't horrible, but probably shouldn't have been made, you can't just replace Macauley Culkin, Joe Pesci, or Daniel Stern. Home Alone 3 had some funny parts, but I don't like when characters are changed in a movie series, view at own risk."
# Label 0
# labels  ['neg', 'pos']

# %%
print(train_ds)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None,), dtype=tf.string, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# ## Now vectorize the dataset using TextVectorization

# %%
# Create a custom standardization function to strip HTML break tags '<br />'.
def standardize_func(input_data):
  lowercase = tf.strings.lower(input_data)
  stripped_html = tf.strings.regex_replace(lowercase, '<br />', ' ')
  return tf.strings.regex_replace(stripped_html,
                                  '[%s]' % re.escape(string.punctuation), '')
  
 
vectorization_layer = tf.keras.layers.TextVectorization(
    standardize=standardize_func,
    max_tokens = vocab_size,
    output_sequence_length = sequence_length,
    output_mode = 'int',

)

#Processed train_ds
p_train_ds = train_ds.map(lambda x, y: x)
vectorization_layer.adapt(p_train_ds)

# %%
#Now just visualize what vectorization layer does
def vectorize_text(text, label):
  text = tf.expand_dims(text, -1)
  return vectorization_layer(text), label

x, y = next(iter(train_ds))
print(x[0], 'shape=', x[0].shape)
print(y[0])
print(vectorize_text(x,y))

# %%
#Just check the vocabulary in from vectorization layer
print(f'{253}-->{vectorization_layer.get_vocabulary()[253]}')
print(f'{998}-->{vectorization_layer.get_vocabulary()[998]}')
print(f'vocab size: {len(vectorization_layer.get_vocabulary())}')

# %% [markdown]
# ### Now prepare for training

# %%
#Configure dataset object for performance
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(AUTOTUNE)
valid_ds = valid_ds.cache().prefetch(AUTOTUNE)
test_ds = test_ds.cache().prefetch(AUTOTUNE)

# %%
#Define the model

model = tf.keras.models.Sequential([
    vectorization_layer,
    tf.keras.layers.Embedding(vocab_size, embedding_size, name='embedding'),
    tf.keras.layers.GlobalAveragePooling1D(),
    Dense(16, activation='relu'),
    Dense(1)
])


model.compile(
    optimizer='adam',
    loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=['accuracy']
)

checkpoint_cb = tf.keras.callbacks.ModelCheckpoint('./checkpoint', verbose = 1,save_best_only=True)

history = model.fit(train_ds, validation_data=valid_ds, epochs = 100, callbacks=[checkpoint_cb])
# Out:
# Epoch 1/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5028
# Epoch 1: val_loss improved from inf to 0.69162, saving model to ./checkpoint
# 20/20 [==============================] - 10s 244ms/step - loss: 0.6925 - accuracy: 0.5028 - val_loss: 0.6916 - val_accuracy: 0.4886
# Epoch 2/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.6906 - accuracy: 0.5028
# Epoch 2: val_loss improved from 0.69162 to 0.68903, saving model to ./checkpoint
# 20/20 [==============================] - 2s 92ms/step - loss: 0.6906 - accuracy: 0.5028 - val_loss: 0.6890 - val_accuracy: 0.4886
# Epoch 3/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.6875 - accuracy: 0.5028
# Epoch 3: val_loss improved from 0.68903 to 0.68491, saving model to ./checkpoint
# 20/20 [==============================] - 2s 101ms/step - loss: 0.6874 - accuracy: 0.5028 - val_loss: 0.6849 - val_accuracy: 0.4886
# Epoch 4/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6823 - accuracy: 0.5028
# Epoch 4: val_loss improved from 0.68491 to 0.67844, saving model to ./checkpoint
# 20/20 [==============================] - 2s 93ms/step - loss: 0.6823 - accuracy: 0.5028 - val_loss: 0.6784 - val_accuracy: 0.4886
# Epoch 5/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6746 - accuracy: 0.5028
# Epoch 5: val_loss improved from 0.67844 to 0.66908, saving model to ./checkpoint
# 20/20 [==============================] - 2s 91ms/step - loss: 0.6746 - accuracy: 0.5028 - val_loss: 0.6691 - val_accuracy: 0.4886
# Epoch 6/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.6640 - accuracy: 0.5028
# Epoch 6: val_loss improved from 0.66908 to 0.65666, saving model to ./checkpoint
# 20/20 [==============================] - 2s 94ms/step - loss: 0.6638 - accuracy: 0.5028 - val_loss: 0.6567 - val_accuracy: 0.4886
# Epoch 7/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6498 - accuracy: 0.5081
# Epoch 7: val_loss improved from 0.65666 to 0.64130, saving model to ./checkpoint
# 20/20 [==============================] - 2s 92ms/step - loss: 0.6498 - accuracy: 0.5081 - val_loss: 0.6413 - val_accuracy: 0.5038
# Epoch 8/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.6331 - accuracy: 0.5356
# Epoch 8: val_loss improved from 0.64130 to 0.62344, saving model to ./checkpoint
# 20/20 [==============================] - 3s 166ms/step - loss: 0.6329 - accuracy: 0.5361 - val_loss: 0.6234 - val_accuracy: 0.5400
# Epoch 9/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6136 - accuracy: 0.5725
# Epoch 9: val_loss improved from 0.62344 to 0.60370, saving model to ./checkpoint
# 20/20 [==============================] - 2s 94ms/step - loss: 0.6136 - accuracy: 0.5725 - val_loss: 0.6037 - val_accuracy: 0.5794
# Epoch 10/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5930 - accuracy: 0.6123
# Epoch 10: val_loss improved from 0.60370 to 0.58288, saving model to ./checkpoint
# 20/20 [==============================] - 2s 104ms/step - loss: 0.5926 - accuracy: 0.6129 - val_loss: 0.5829 - val_accuracy: 0.6174
# Epoch 11/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5710 - accuracy: 0.6524
# Epoch 11: val_loss improved from 0.58288 to 0.56167, saving model to ./checkpoint
# 20/20 [==============================] - 2s 91ms/step - loss: 0.5706 - accuracy: 0.6529 - val_loss: 0.5617 - val_accuracy: 0.6510
# Epoch 12/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5489 - accuracy: 0.6861
# Epoch 12: val_loss improved from 0.56167 to 0.54081, saving model to ./checkpoint
# 20/20 [==============================] - 2s 92ms/step - loss: 0.5485 - accuracy: 0.6863 - val_loss: 0.5408 - val_accuracy: 0.6806
# Epoch 13/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5273 - accuracy: 0.7168
# Epoch 13: val_loss improved from 0.54081 to 0.52079, saving model to ./checkpoint
# 20/20 [==============================] - 2s 94ms/step - loss: 0.5269 - accuracy: 0.7170 - val_loss: 0.5208 - val_accuracy: 0.7074
# Epoch 14/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5066 - accuracy: 0.7392
# Epoch 14: val_loss improved from 0.52079 to 0.50205, saving model to ./checkpoint
# 20/20 [==============================] - 2s 93ms/step - loss: 0.5062 - accuracy: 0.7391 - val_loss: 0.5021 - val_accuracy: 0.7264
# Epoch 15/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4871 - accuracy: 0.7574
# Epoch 15: val_loss improved from 0.50205 to 0.48511, saving model to ./checkpoint
# 20/20 [==============================] - 2s 106ms/step - loss: 0.4871 - accuracy: 0.7574 - val_loss: 0.4851 - val_accuracy: 0.7442
# Epoch 16/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4703 - accuracy: 0.7709
# Epoch 16: val_loss improved from 0.48511 to 0.47021, saving model to ./checkpoint
# 20/20 [==============================] - 2s 128ms/step - loss: 0.4699 - accuracy: 0.7710 - val_loss: 0.4702 - val_accuracy: 0.7584
# Epoch 17/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4552 - accuracy: 0.7809
# Epoch 17: val_loss improved from 0.47021 to 0.45734, saving model to ./checkpoint
# 20/20 [==============================] - 2s 93ms/step - loss: 0.4548 - accuracy: 0.7810 - val_loss: 0.4573 - val_accuracy: 0.7696
# Epoch 18/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4421 - accuracy: 0.7902
# Epoch 18: val_loss improved from 0.45734 to 0.44634, saving model to ./checkpoint
# 20/20 [==============================] - 2s 93ms/step - loss: 0.4417 - accuracy: 0.7902 - val_loss: 0.4463 - val_accuracy: 0.7782
# Epoch 19/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4307 - accuracy: 0.7972
# Epoch 19: val_loss improved from 0.44634 to 0.43697, saving model to ./checkpoint
# 20/20 [==============================] - 2s 96ms/step - loss: 0.4303 - accuracy: 0.7973 - val_loss: 0.4370 - val_accuracy: 0.7874
# Epoch 20/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4208 - accuracy: 0.8029
# Epoch 20: val_loss improved from 0.43697 to 0.42896, saving model to ./checkpoint
# 20/20 [==============================] - 2s 94ms/step - loss: 0.4204 - accuracy: 0.8030 - val_loss: 0.4290 - val_accuracy: 0.7922
# Epoch 21/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4122 - accuracy: 0.8072
# Epoch 21: val_loss improved from 0.42896 to 0.42207, saving model to ./checkpoint
# 20/20 [==============================] - 2s 94ms/step - loss: 0.4118 - accuracy: 0.8073 - val_loss: 0.4221 - val_accuracy: 0.7964
# Epoch 22/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4042 - accuracy: 0.8116
# Epoch 22: val_loss improved from 0.42207 to 0.41610, saving model to ./checkpoint
# 20/20 [==============================] - 2s 109ms/step - loss: 0.4042 - accuracy: 0.8116 - val_loss: 0.4161 - val_accuracy: 0.7992
# Epoch 23/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3975 - accuracy: 0.8162
# Epoch 23: val_loss improved from 0.41610 to 0.41090, saving model to ./checkpoint
# 20/20 [==============================] - 2s 95ms/step - loss: 0.3975 - accuracy: 0.8162 - val_loss: 0.4109 - val_accuracy: 0.8020
# Epoch 24/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3920 - accuracy: 0.8188
# Epoch 24: val_loss improved from 0.41090 to 0.40634, saving model to ./checkpoint
# 20/20 [==============================] - 2s 93ms/step - loss: 0.3915 - accuracy: 0.8187 - val_loss: 0.4063 - val_accuracy: 0.8054
# Epoch 25/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3862 - accuracy: 0.8213
# Epoch 25: val_loss improved from 0.40634 to 0.40230, saving model to ./checkpoint
# 20/20 [==============================] - 2s 93ms/step - loss: 0.3862 - accuracy: 0.8213 - val_loss: 0.4023 - val_accuracy: 0.8084
# Epoch 26/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3813 - accuracy: 0.8245
# Epoch 26: val_loss improved from 0.40230 to 0.39872, saving model to ./checkpoint
# 20/20 [==============================] - 2s 94ms/step - loss: 0.3813 - accuracy: 0.8245 - val_loss: 0.3987 - val_accuracy: 0.8106
# Epoch 27/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3775 - accuracy: 0.8270
# Epoch 27: val_loss improved from 0.39872 to 0.39552, saving model to ./checkpoint
# 20/20 [==============================] - 2s 93ms/step - loss: 0.3770 - accuracy: 0.8273 - val_loss: 0.3955 - val_accuracy: 0.8120
# Epoch 28/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3730 - accuracy: 0.8299
# Epoch 28: val_loss improved from 0.39552 to 0.39265, saving model to ./checkpoint
# 20/20 [==============================] - 2s 105ms/step - loss: 0.3730 - accuracy: 0.8299 - val_loss: 0.3927 - val_accuracy: 0.8130
# Epoch 29/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3699 - accuracy: 0.8317
# Epoch 29: val_loss improved from 0.39265 to 0.39007, saving model to ./checkpoint
# 20/20 [==============================] - 2s 94ms/step - loss: 0.3693 - accuracy: 0.8321 - val_loss: 0.3901 - val_accuracy: 0.8144
# Epoch 30/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3666 - accuracy: 0.8330
# Epoch 30: val_loss improved from 0.39007 to 0.38771, saving model to ./checkpoint
# 20/20 [==============================] - 2s 96ms/step - loss: 0.3660 - accuracy: 0.8334 - val_loss: 0.3877 - val_accuracy: 0.8160
# Epoch 31/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3635 - accuracy: 0.8345
# Epoch 31: val_loss improved from 0.38771 to 0.38558, saving model to ./checkpoint
# 20/20 [==============================] - 2s 95ms/step - loss: 0.3629 - accuracy: 0.8350 - val_loss: 0.3856 - val_accuracy: 0.8178
# Epoch 32/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3600 - accuracy: 0.8364
# Epoch 32: val_loss improved from 0.38558 to 0.38365, saving model to ./checkpoint
# 20/20 [==============================] - 2s 93ms/step - loss: 0.3600 - accuracy: 0.8364 - val_loss: 0.3837 - val_accuracy: 0.8196
# Epoch 33/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3581 - accuracy: 0.8377
# Epoch 33: val_loss improved from 0.38365 to 0.38189, saving model to ./checkpoint
# 20/20 [==============================] - 2s 94ms/step - loss: 0.3574 - accuracy: 0.8385 - val_loss: 0.3819 - val_accuracy: 0.8212
# Epoch 34/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3549 - accuracy: 0.8399
# Epoch 34: val_loss improved from 0.38189 to 0.38028, saving model to ./checkpoint
# 20/20 [==============================] - 3s 151ms/step - loss: 0.3549 - accuracy: 0.8399 - val_loss: 0.3803 - val_accuracy: 0.8218
# Epoch 35/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3534 - accuracy: 0.8401
# Epoch 35: val_loss improved from 0.38028 to 0.37882, saving model to ./checkpoint
# 20/20 [==============================] - 2s 93ms/step - loss: 0.3527 - accuracy: 0.8407 - val_loss: 0.3788 - val_accuracy: 0.8228
# Epoch 36/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3505 - accuracy: 0.8423
# Epoch 36: val_loss improved from 0.37882 to 0.37749, saving model to ./checkpoint
# 20/20 [==============================] - 2s 93ms/step - loss: 0.3505 - accuracy: 0.8423 - val_loss: 0.3775 - val_accuracy: 0.8242
# Epoch 37/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3493 - accuracy: 0.8427
# Epoch 37: val_loss improved from 0.37749 to 0.37627, saving model to ./checkpoint
# 20/20 [==============================] - 2s 92ms/step - loss: 0.3486 - accuracy: 0.8434 - val_loss: 0.3763 - val_accuracy: 0.8260
# Epoch 38/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3467 - accuracy: 0.8438
# Epoch 38: val_loss improved from 0.37627 to 0.37517, saving model to ./checkpoint
# 20/20 [==============================] - 2s 92ms/step - loss: 0.3467 - accuracy: 0.8438 - val_loss: 0.3752 - val_accuracy: 0.8262
# Epoch 39/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3450 - accuracy: 0.8449
# Epoch 39: val_loss improved from 0.37517 to 0.37415, saving model to ./checkpoint
# 20/20 [==============================] - 2s 94ms/step - loss: 0.3450 - accuracy: 0.8449 - val_loss: 0.3742 - val_accuracy: 0.8278
# Epoch 40/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3434 - accuracy: 0.8461
# Epoch 40: val_loss improved from 0.37415 to 0.37323, saving model to ./checkpoint
# 20/20 [==============================] - 2s 104ms/step - loss: 0.3434 - accuracy: 0.8461 - val_loss: 0.3732 - val_accuracy: 0.8288
# Epoch 41/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3427 - accuracy: 0.8460
# Epoch 41: val_loss improved from 0.37323 to 0.37237, saving model to ./checkpoint
# 20/20 [==============================] - 2s 96ms/step - loss: 0.3418 - accuracy: 0.8466 - val_loss: 0.3724 - val_accuracy: 0.8290
# Epoch 42/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3404 - accuracy: 0.8472
# Epoch 42: val_loss improved from 0.37237 to 0.37161, saving model to ./checkpoint
# 20/20 [==============================] - 2s 94ms/step - loss: 0.3404 - accuracy: 0.8472 - val_loss: 0.3716 - val_accuracy: 0.8300
# Epoch 43/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3391 - accuracy: 0.8481
# Epoch 43: val_loss improved from 0.37161 to 0.37092, saving model to ./checkpoint
# 20/20 [==============================] - 2s 94ms/step - loss: 0.3391 - accuracy: 0.8481 - val_loss: 0.3709 - val_accuracy: 0.8308
# Epoch 44/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3387 - accuracy: 0.8481
# Epoch 44: val_loss improved from 0.37092 to 0.37028, saving model to ./checkpoint
# 20/20 [==============================] - 2s 96ms/step - loss: 0.3378 - accuracy: 0.8487 - val_loss: 0.3703 - val_accuracy: 0.8312
# Epoch 45/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3366 - accuracy: 0.8489
# Epoch 45: val_loss improved from 0.37028 to 0.36972, saving model to ./checkpoint
# 20/20 [==============================] - 2s 94ms/step - loss: 0.3366 - accuracy: 0.8489 - val_loss: 0.3697 - val_accuracy: 0.8306
# Epoch 46/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3365 - accuracy: 0.8490
# Epoch 46: val_loss improved from 0.36972 to 0.36920, saving model to ./checkpoint
# 20/20 [==============================] - 2s 110ms/step - loss: 0.3355 - accuracy: 0.8496 - val_loss: 0.3692 - val_accuracy: 0.8310
# Epoch 47/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3344 - accuracy: 0.8501
# Epoch 47: val_loss improved from 0.36920 to 0.36873, saving model to ./checkpoint
# 20/20 [==============================] - 2s 116ms/step - loss: 0.3344 - accuracy: 0.8501 - val_loss: 0.3687 - val_accuracy: 0.8312
# Epoch 48/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3334 - accuracy: 0.8507
# Epoch 48: val_loss improved from 0.36873 to 0.36832, saving model to ./checkpoint
# 20/20 [==============================] - 2s 96ms/step - loss: 0.3334 - accuracy: 0.8507 - val_loss: 0.3683 - val_accuracy: 0.8310
# Epoch 49/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3335 - accuracy: 0.8506
# Epoch 49: val_loss improved from 0.36832 to 0.36795, saving model to ./checkpoint
# 20/20 [==============================] - 2s 94ms/step - loss: 0.3325 - accuracy: 0.8512 - val_loss: 0.3679 - val_accuracy: 0.8310
# Epoch 50/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3316 - accuracy: 0.8518
# Epoch 50: val_loss improved from 0.36795 to 0.36762, saving model to ./checkpoint
# 20/20 [==============================] - 2s 96ms/step - loss: 0.3316 - accuracy: 0.8518 - val_loss: 0.3676 - val_accuracy: 0.8324
# Epoch 51/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3308 - accuracy: 0.8526
# Epoch 51: val_loss improved from 0.36762 to 0.36733, saving model to ./checkpoint
# 20/20 [==============================] - 2s 93ms/step - loss: 0.3308 - accuracy: 0.8526 - val_loss: 0.3673 - val_accuracy: 0.8326
# Epoch 52/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3300 - accuracy: 0.8529
# Epoch 52: val_loss improved from 0.36733 to 0.36706, saving model to ./checkpoint
# 20/20 [==============================] - 2s 94ms/step - loss: 0.3300 - accuracy: 0.8529 - val_loss: 0.3671 - val_accuracy: 0.8324
# Epoch 53/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3303 - accuracy: 0.8526
# Epoch 53: val_loss improved from 0.36706 to 0.36683, saving model to ./checkpoint
# 20/20 [==============================] - 2s 103ms/step - loss: 0.3292 - accuracy: 0.8533 - val_loss: 0.3668 - val_accuracy: 0.8326
# Epoch 54/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3296 - accuracy: 0.8531
# Epoch 54: val_loss improved from 0.36683 to 0.36664, saving model to ./checkpoint
# 20/20 [==============================] - 2s 92ms/step - loss: 0.3285 - accuracy: 0.8536 - val_loss: 0.3666 - val_accuracy: 0.8322
# Epoch 55/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3290 - accuracy: 0.8536
# Epoch 55: val_loss improved from 0.36664 to 0.36648, saving model to ./checkpoint
# 20/20 [==============================] - 2s 95ms/step - loss: 0.3278 - accuracy: 0.8541 - val_loss: 0.3665 - val_accuracy: 0.8322
# Epoch 56/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3272 - accuracy: 0.8543
# Epoch 56: val_loss improved from 0.36648 to 0.36632, saving model to ./checkpoint
# 20/20 [==============================] - 2s 95ms/step - loss: 0.3272 - accuracy: 0.8543 - val_loss: 0.3663 - val_accuracy: 0.8322
# Epoch 57/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3277 - accuracy: 0.8544
# Epoch 57: val_loss improved from 0.36632 to 0.36620, saving model to ./checkpoint
# 20/20 [==============================] - 2s 95ms/step - loss: 0.3266 - accuracy: 0.8550 - val_loss: 0.3662 - val_accuracy: 0.8324
# Epoch 58/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3272 - accuracy: 0.8547
# Epoch 58: val_loss improved from 0.36620 to 0.36611, saving model to ./checkpoint
# 20/20 [==============================] - 2s 106ms/step - loss: 0.3260 - accuracy: 0.8553 - val_loss: 0.3661 - val_accuracy: 0.8324
# Epoch 59/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3267 - accuracy: 0.8547
# Epoch 59: val_loss improved from 0.36611 to 0.36603, saving model to ./checkpoint
# 20/20 [==============================] - 2s 95ms/step - loss: 0.3255 - accuracy: 0.8554 - val_loss: 0.3660 - val_accuracy: 0.8318
# Epoch 60/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3250 - accuracy: 0.8555
# Epoch 60: val_loss improved from 0.36603 to 0.36597, saving model to ./checkpoint
# 20/20 [==============================] - 2s 96ms/step - loss: 0.3250 - accuracy: 0.8555 - val_loss: 0.3660 - val_accuracy: 0.8314
# Epoch 61/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3257 - accuracy: 0.8551
# Epoch 61: val_loss improved from 0.36597 to 0.36590, saving model to ./checkpoint
# 20/20 [==============================] - 2s 93ms/step - loss: 0.3245 - accuracy: 0.8557 - val_loss: 0.3659 - val_accuracy: 0.8316
# Epoch 62/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3252 - accuracy: 0.8547
# Epoch 62: val_loss improved from 0.36590 to 0.36585, saving model to ./checkpoint
# 20/20 [==============================] - 2s 94ms/step - loss: 0.3240 - accuracy: 0.8553 - val_loss: 0.3659 - val_accuracy: 0.8318
# Epoch 63/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3248 - accuracy: 0.8552
# Epoch 63: val_loss improved from 0.36585 to 0.36583, saving model to ./checkpoint
# 20/20 [==============================] - 2s 95ms/step - loss: 0.3236 - accuracy: 0.8558 - val_loss: 0.3658 - val_accuracy: 0.8314
# Epoch 64/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3243 - accuracy: 0.8554
# Epoch 64: val_loss improved from 0.36583 to 0.36579, saving model to ./checkpoint
# 20/20 [==============================] - 2s 93ms/step - loss: 0.3231 - accuracy: 0.8560 - val_loss: 0.3658 - val_accuracy: 0.8320
# Epoch 65/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3239 - accuracy: 0.8559
# Epoch 65: val_loss improved from 0.36579 to 0.36578, saving model to ./checkpoint
# 20/20 [==============================] - 2s 105ms/step - loss: 0.3227 - accuracy: 0.8564 - val_loss: 0.3658 - val_accuracy: 0.8320
# Epoch 66/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3223 - accuracy: 0.8568
# Epoch 66: val_loss improved from 0.36578 to 0.36577, saving model to ./checkpoint
# 20/20 [==============================] - 2s 93ms/step - loss: 0.3223 - accuracy: 0.8568 - val_loss: 0.3658 - val_accuracy: 0.8322
# Epoch 67/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3220 - accuracy: 0.8571
# Epoch 67: val_loss improved from 0.36577 to 0.36576, saving model to ./checkpoint
# 20/20 [==============================] - 2s 92ms/step - loss: 0.3220 - accuracy: 0.8571 - val_loss: 0.3658 - val_accuracy: 0.8334
# Epoch 68/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3229 - accuracy: 0.8564
# Epoch 68: val_loss improved from 0.36576 to 0.36574, saving model to ./checkpoint
# 20/20 [==============================] - 2s 94ms/step - loss: 0.3216 - accuracy: 0.8569 - val_loss: 0.3657 - val_accuracy: 0.8332
# Epoch 69/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3213 - accuracy: 0.8569
# Epoch 69: val_loss improved from 0.36574 to 0.36574, saving model to ./checkpoint
# 20/20 [==============================] - 2s 93ms/step - loss: 0.3213 - accuracy: 0.8569 - val_loss: 0.3657 - val_accuracy: 0.8338
# Epoch 70/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3222 - accuracy: 0.8570
# Epoch 70: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 54ms/step - loss: 0.3209 - accuracy: 0.8576 - val_loss: 0.3658 - val_accuracy: 0.8336
# Epoch 71/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3219 - accuracy: 0.8570
# Epoch 71: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 54ms/step - loss: 0.3206 - accuracy: 0.8576 - val_loss: 0.3658 - val_accuracy: 0.8342
# Epoch 72/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3203 - accuracy: 0.8575
# Epoch 72: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 54ms/step - loss: 0.3203 - accuracy: 0.8575 - val_loss: 0.3658 - val_accuracy: 0.8340
# Epoch 73/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3200 - accuracy: 0.8576
# Epoch 73: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 55ms/step - loss: 0.3200 - accuracy: 0.8576 - val_loss: 0.3658 - val_accuracy: 0.8344
# Epoch 74/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3197 - accuracy: 0.8580
# Epoch 74: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 55ms/step - loss: 0.3197 - accuracy: 0.8580 - val_loss: 0.3659 - val_accuracy: 0.8346
# Epoch 75/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3208 - accuracy: 0.8575
# Epoch 75: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 54ms/step - loss: 0.3195 - accuracy: 0.8582 - val_loss: 0.3659 - val_accuracy: 0.8348
# Epoch 76/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3205 - accuracy: 0.8573
# Epoch 76: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 73ms/step - loss: 0.3192 - accuracy: 0.8579 - val_loss: 0.3660 - val_accuracy: 0.8348
# Epoch 77/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3190 - accuracy: 0.8580
# Epoch 77: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 53ms/step - loss: 0.3190 - accuracy: 0.8580 - val_loss: 0.3660 - val_accuracy: 0.8350
# Epoch 78/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3201 - accuracy: 0.8576
# Epoch 78: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 55ms/step - loss: 0.3187 - accuracy: 0.8582 - val_loss: 0.3661 - val_accuracy: 0.8348
# Epoch 79/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3185 - accuracy: 0.8582
# Epoch 79: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 54ms/step - loss: 0.3185 - accuracy: 0.8582 - val_loss: 0.3661 - val_accuracy: 0.8346
# Epoch 80/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3183 - accuracy: 0.8583
# Epoch 80: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 56ms/step - loss: 0.3183 - accuracy: 0.8583 - val_loss: 0.3662 - val_accuracy: 0.8350
# Epoch 81/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3195 - accuracy: 0.8580
# Epoch 81: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 53ms/step - loss: 0.3181 - accuracy: 0.8586 - val_loss: 0.3662 - val_accuracy: 0.8346
# Epoch 82/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3193 - accuracy: 0.8581
# Epoch 82: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 53ms/step - loss: 0.3179 - accuracy: 0.8587 - val_loss: 0.3663 - val_accuracy: 0.8346
# Epoch 83/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3191 - accuracy: 0.8584
# Epoch 83: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 53ms/step - loss: 0.3177 - accuracy: 0.8590 - val_loss: 0.3664 - val_accuracy: 0.8344
# Epoch 84/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3175 - accuracy: 0.8591
# Epoch 84: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 53ms/step - loss: 0.3175 - accuracy: 0.8591 - val_loss: 0.3664 - val_accuracy: 0.8342
# Epoch 85/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3173 - accuracy: 0.8593
# Epoch 85: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 54ms/step - loss: 0.3173 - accuracy: 0.8593 - val_loss: 0.3665 - val_accuracy: 0.8342
# Epoch 86/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3186 - accuracy: 0.8589
# Epoch 86: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 55ms/step - loss: 0.3172 - accuracy: 0.8594 - val_loss: 0.3666 - val_accuracy: 0.8346
# Epoch 87/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3170 - accuracy: 0.8594
# Epoch 87: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 56ms/step - loss: 0.3170 - accuracy: 0.8594 - val_loss: 0.3666 - val_accuracy: 0.8344
# Epoch 88/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3183 - accuracy: 0.8590
# Epoch 88: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 56ms/step - loss: 0.3169 - accuracy: 0.8596 - val_loss: 0.3667 - val_accuracy: 0.8344
# Epoch 89/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3167 - accuracy: 0.8597
# Epoch 89: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 54ms/step - loss: 0.3167 - accuracy: 0.8597 - val_loss: 0.3668 - val_accuracy: 0.8342
# Epoch 90/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3166 - accuracy: 0.8598
# Epoch 90: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 53ms/step - loss: 0.3166 - accuracy: 0.8598 - val_loss: 0.3668 - val_accuracy: 0.8342
# Epoch 91/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3164 - accuracy: 0.8597
# Epoch 91: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 55ms/step - loss: 0.3164 - accuracy: 0.8597 - val_loss: 0.3669 - val_accuracy: 0.8340
# Epoch 92/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3163 - accuracy: 0.8598
# Epoch 92: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 54ms/step - loss: 0.3163 - accuracy: 0.8598 - val_loss: 0.3670 - val_accuracy: 0.8336
# Epoch 93/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3162 - accuracy: 0.8598
# Epoch 93: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 54ms/step - loss: 0.3162 - accuracy: 0.8598 - val_loss: 0.3670 - val_accuracy: 0.8326
# Epoch 94/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3175 - accuracy: 0.8593
# Epoch 94: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 55ms/step - loss: 0.3161 - accuracy: 0.8598 - val_loss: 0.3671 - val_accuracy: 0.8330
# Epoch 95/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3174 - accuracy: 0.8594
# Epoch 95: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 54ms/step - loss: 0.3159 - accuracy: 0.8600 - val_loss: 0.3672 - val_accuracy: 0.8324
# Epoch 96/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3173 - accuracy: 0.8592
# Epoch 96: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 56ms/step - loss: 0.3158 - accuracy: 0.8598 - val_loss: 0.3672 - val_accuracy: 0.8326
# Epoch 97/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3157 - accuracy: 0.8599
# Epoch 97: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 55ms/step - loss: 0.3157 - accuracy: 0.8599 - val_loss: 0.3673 - val_accuracy: 0.8330
# Epoch 98/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3171 - accuracy: 0.8594
# Epoch 98: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 54ms/step - loss: 0.3156 - accuracy: 0.8601 - val_loss: 0.3673 - val_accuracy: 0.8332
# Epoch 99/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3155 - accuracy: 0.8602
# Epoch 99: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 56ms/step - loss: 0.3155 - accuracy: 0.8602 - val_loss: 0.3674 - val_accuracy: 0.8330
# Epoch 100/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3169 - accuracy: 0.8598
# Epoch 100: val_loss did not improve from 0.36574
# 20/20 [==============================] - 1s 56ms/step - loss: 0.3154 - accuracy: 0.8605 - val_loss: 0.3674 - val_accuracy: 0.8328

# %%
def summarize_diagnostic(history, path = '', description = None):
    plt.figure(figsize=(10,10))
    plt.figtext(0, 1, description, fontsize=15)
    plt.subplot(211)
    plt.title("Loss")
    plt.plot(history.history['loss'], color="blue", label="train loss")
    plt.plot(history.history['val_loss'], color="red", label="validation loss")
    plt.legend()
    plt.subplot(212)
    plt.title("Accuracy")
    plt.plot(history.history['accuracy'], color="blue", label="train accuracy")
    plt.plot(history.history['val_accuracy'], color="red", label="validation accuracy")
    plt.legend()
    if(path!= ''):
        plt.rcParams['savefig.facecolor'] = 'white'
        plt.savefig(path, dpi = 100, bbox_inches = 'tight')
    
summarize_diagnostic(history)

# %%
 1
